# %% [markdown]
# # Explore Currupted MNIST Dataset

# %%
import data
import matplotlib.pyplot as plt

train_dataloader, test_dataloader = data.mnist()

# %%
#Print shape of first training image
print(train_dataloader.dataset.images[0].shape)
# Out:
# torch.Size([28, 28])

# %%
#Plot first 10 image from training data
for i, (images, labels) in enumerate(train_dataloader):
    if i == 10:
        break
    plt.subplot(2, 5, i+1)
    plt.imshow(images[0], cmap='gray')
    plt.title('label: {}'.format(labels[0]))
